# %%
import json



def load_file(file_path):

    """

    :param file_path: path to the json file

    :return: an array in which each entry is tuple [review, classification label]

    """

    with open(file_path) as json_file:

        raw_data = json.load(json_file)

        return convert_data(raw_data)
        # return raw_data



def convert_data(raw_data):

    data = []

    for elem in raw_data:

        data.append([elem["comment"], elem["label"]])

    return data

# %%
import pandas as pd

# import datasets
bug_data = load_file("./data/Bug_tt.json")
rating_data = load_file("./data/Rating_tt.json")
feature_data = load_file("./data/Feature_tt.json")
experience_data = load_file("./data/UserExperience_tt.json")

df_bug = pd.DataFrame(bug_data, columns = ['text', 'label'])
df_rating = pd.DataFrame(rating_data, columns = ['text', 'label'])
df_feature = pd.DataFrame(feature_data, columns = ['text', 'label'])
df_experience = pd.DataFrame(experience_data, columns = ['text', 'label'])

# %%
# df_bug = pd.DataFrame(bug_data)

# %%
df_feature
# Out:
#                                                   text        label
# 0    Can't open the apps\tWhenever I open the apps ...      Feature
# 1                                 App runs too slow!!!      Feature
# 2    This is a great app. I've used ODB on my iPod ...      Feature
# 3    I listen to it a lot. However, it will once in...      Feature
# 4    Easy to use. I wished it was able to determine...      Feature
# ..                                                 ...          ...
# 611  Good bt not satisfied :(\tCan't reply.. no tag...  Not_Feature
# 612                              Improving. Way to go.  Not_Feature
# 613                                        Passt\tNaja  Not_Feature
# 614  Better than it used to be...\tStill needs sign...  Not_Feature
# 615                                               Good  Not_Feature
#
# [616 rows x 2 columns]

# %%
# remove non-labels
df_bug = df_bug[df_bug['label'] == 'Bug']
df_rating = df_rating[df_rating['label'] == 'Rating']
df_feature = df_feature[df_feature['label'] == 'Feature']
df_experience = df_experience[df_experience['label'] == 'UserExperience']

# %%
df_feature
# Out:
#                                                   text    label
# 0    cannot open the apps\twhenever i open the apps...  Feature
# 1                                 app runs too slow     Feature
# 2    this is a great app  i have used odb on my ipo...  Feature
# 3    i listen to it a lot  however  it will once in...  Feature
# 4    easy to use  i wished it was able to determine...  Feature
# ..                                                 ...      ...
# 290  even google drive can refresh folders   some s...  Feature
# 291  some places that had menus on the old version ...  Feature
# 292  the new update loads slower  closes out on me ...  Feature
# 293  cannot get enough\tbrilliant app switched to a...  Feature
# 294  video playback sucks\tthis is a wonderful app ...  Feature
#
# [295 rows x 2 columns]

# %% [markdown]
# Basic text cleaning

# %%
def clean_text(df):
  df['text'] = df['text'].str.replace("\r", " ")
  df['text'] = df['text'].str.replace("\n", " ")
  df['text'] = df['text'].str.replace('"', '')
  df['text'] = df['text'].str.lower()
  return df

df_bug = clean_text(df_bug)
df_rating = clean_text(df_rating)
df_feature = clean_text(df_feature)
df_experience = clean_text(df_experience)
# Out:
# /var/folders/xg/bm1fvvg52c59ys41szx2b2h80000gn/T/ipykernel_82981/644821228.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.replace("\r", " ")
# /var/folders/xg/bm1fvvg52c59ys41szx2b2h80000gn/T/ipykernel_82981/644821228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.replace("\n", " ")
# /var/folders/xg/bm1fvvg52c59ys41szx2b2h80000gn/T/ipykernel_82981/644821228.py:4: SettingWithCopyWarning:
# ...

# %%
df_bug
# Out:
#                                                   text label
# 0    besides the occasional crash, this is an amazi...   Bug
# 1    this could be a great app if it was predictabl...   Bug
# 2    i can't open since the last 2 updates pop-ups ...   Bug
# 3    use to love this app but it's not working afte...   Bug
# 4    urrrrm\tafter my third re installing, it final...   Bug
# ..                                                 ...   ...
# 365                   fck\tfix this cause always error   Bug
# 366  please fix this\tidk it uninstalls in my phone...   Bug
# 367  i have a factory refurbished older ipad and it...   Bug
# 368  older versions of this app used to allow me to...   Bug
# 369  it's way too slow!! loved this app then i upda...   Bug
#
# [370 rows x 2 columns]

# %%
# %pip install contractions

import contractions

def expand_contractions(df):
  for index, row in df.iterrows():
    df['text'][index] = contractions.fix(row['text'])
  return df


df_bug = expand_contractions(df_bug)
df_rating = expand_contractions(df_rating)
df_feature = expand_contractions(df_feature)
df_experience = expand_contractions(df_experience)
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# /var/folders/xg/bm1fvvg52c59ys41szx2b2h80000gn/T/ipykernel_82981/3433164488.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...

# %%
df_bug
# Out:
#                                                   text label
# 0    besides the occasional crash, this is an amazi...   Bug
# 1    this could be a great app if it was predictabl...   Bug
# 2    i cannot open since the last 2 updates pop-ups...   Bug
# 3    use to love this app but it is not working aft...   Bug
# 4    urrrrm\tafter my third re installing, it final...   Bug
# ..                                                 ...   ...
# 365                 fck\tfix this because always error   Bug
# 366  please fix this\ti do not know it uninstalls i...   Bug
# 367  i have a factory refurbished older ipad and it...   Bug
# 368  older versions of this app used to allow me to...   Bug
# 369  it is way too slow!! loved this app then i upd...   Bug
#
# [370 rows x 2 columns]

# %%
# remove punctuations

def remove_puncts(df):
  punctuation_signs = list("?:!.,;")

  for punct_sign in punctuation_signs:
      df['text'] = df['text'].str.replace(punct_sign, ' ', regex=False)

  df['text'] = df['text'].str.replace("'s", "", regex=True)
  return df

df_bug = remove_puncts(df_bug)
df_rating = remove_puncts(df_rating)
df_feature = remove_puncts(df_feature)
df_experience = remove_puncts(df_experience)
# Out:
# /var/folders/xg/bm1fvvg52c59ys41szx2b2h80000gn/T/ipykernel_82981/3245397383.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.replace(punct_sign, ' ', regex=False)
# /var/folders/xg/bm1fvvg52c59ys41szx2b2h80000gn/T/ipykernel_82981/3245397383.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.replace("'s", "", regex=True)

# %%
df_bug
# Out:
#                                                   text label
# 0    besides the occasional crash  this is an amazi...   Bug
# 1    this could be a great app if it was predictabl...   Bug
# 2    i cannot open since the last 2 updates pop-ups...   Bug
# 3    use to love this app but it is not working aft...   Bug
# 4    urrrrm\tafter my third re installing  it final...   Bug
# ..                                                 ...   ...
# 365                 fck\tfix this because always error   Bug
# 366  please fix this\ti do not know it uninstalls i...   Bug
# 367  i have a factory refurbished older ipad and it...   Bug
# 368  older versions of this app used to allow me to...   Bug
# 369  it is way too slow   loved this app then i upd...   Bug
#
# [370 rows x 2 columns]

# %% [markdown]
# NLP Tricks

# %%
# %pip install nltk

import nltk

nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/jordantab/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jordantab/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# lemmatization

from nltk.stem import WordNetLemmatizer

def lemmatize(df):
  wordnet_lemmatizer = WordNetLemmatizer()
  nrows = len(df)
  lemmatized_text_list = []

  for index, row in df.iterrows():  # Use iterrows() to correctly iterate over DataFrame rows
      # Create an empty list which will contain the lemmatized words
      lemmatized_list = []

      # Save the text and its words into an object
      text = row['text']
      text_words = text.split(" ")

      # Iterate through every word to lemmatize
      for word in text_words:
          lemmatized_list.append(wordnet_lemmatizer.lemmatize(word, pos="v"))

      # Join the list
      lemmatized_text = " ".join(lemmatized_list)

      # Append to the list containing the texts
      lemmatized_text_list.append(lemmatized_text)

  # Set the 'text' column in df to the list of lemmatized texts AFTER the loop
  df.loc[:,'text'] = lemmatized_text_list
  return df

# %%
# df_bug = lemmatize(df_bug)
# df_rating = lemmatize(df_rating)
# df_feature = lemmatize(df_feature)
# df_experience = lemmatize(df_experience)

# %%
from nltk.corpus import stopwords
# Downloading the stop words list
nltk.download('stopwords')
stop_words = list(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jordantab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_bug['text'].head(10)
# Out:
# 0    besides the occasional crash  this is an amazi...
# 1    this could be a great app if it was predictabl...
# 2    i cannot open since the last 2 updates pop-ups...
# 3    use to love this app but it is not working aft...
# 4    urrrrm\tafter my third re installing  it final...
# 5    this app serves its purpose for me perfectly e...
# 6    album function needs improvement\tcurrent vers...
# 7    i am very disappointed that i cannot open most...
# 8    needs to be updated \twas fun & challenging  d...
# 9    it is good if you want to browse but is horrib...
# Name: text, dtype: object

# %%
# remove stop words function

def remove_stop_words(df):
  for stop_word in stop_words:
    regex_stopword = r"\b" + stop_word + r"\b"
    df.loc[:, 'text'] = df['text'].str.replace(regex_stopword, '', regex=True)
  return df

# %%
# remove stop words
# df_bug = remove_stop_words(df_bug)
# df_rating = remove_stop_words(df_rating)
# df_feature = remove_stop_words(df_feature)
# df_experience = remove_stop_words(df_experience)

# %%
df_bug['text']
# Out:
# 0      besides the occasional crash  this is an amazi...
# 1      this could be a great app if it was predictabl...
# 2      i cannot open since the last 2 updates pop-ups...
# 3      use to love this app but it is not working aft...
# 4      urrrrm\tafter my third re installing  it final...
#                              ...
# 365                   fck\tfix this because always error
# 366    please fix this\ti do not know it uninstalls i...
# 367    i have a factory refurbished older ipad and it...
# 368    older versions of this app used to allow me to...
# 369    it is way too slow   loved this app then i upd...
# Name: text, Length: 370, dtype: object

# %% [markdown]
# Combine datasets

# %%
from sklearn.utils import shuffle

combined_df = pd.concat([df_bug, df_rating, df_feature, df_experience], axis=0)
combined_df = shuffle(combined_df, random_state=42)

# %%
combined_df
# Out:
#                                                   text           label
# 39       great app for travelers  highly recommend it   UserExperience
# 124                                   love traveling            Rating
# 279                               awsis\tvery nice app          Rating
# 284  lousy\tthis print tool is not worth your money...          Rating
# 213  keeps crashing \tinstalled  on the loading pag...         Feature
# ..                                                 ...             ...
# 60   as a commercial pilot i use this app all the t...  UserExperience
# 95   works perfect and picks up a ton of stations t...  UserExperience
# 259  awesome pdf performance\tlatest update has imp...  UserExperience
# 120  it is impossible to refine a hotel search for ...         Feature
# 91   this is the best app ever it make hilarious vi...  UserExperience
#
# [1405 rows x 2 columns]

# %%
# encode labels
label_mapping = {
    'Bug': 1,
    'Rating': 2,
    'Feature': 3,
    'UserExperience': 4
}
combined_df['label'] = combined_df['label'].replace(label_mapping)
# Out:
# /var/folders/xg/bm1fvvg52c59ys41szx2b2h80000gn/T/ipykernel_82981/3256040583.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_df['label'] = combined_df['label'].replace(label_mapping)

# %%
combined_df
# Out:
#                                                   text  label
# 39       great app for travelers  highly recommend it       4
# 124                                   love traveling        2
# 279                               awsis\tvery nice app      2
# 284  lousy\tthis print tool is not worth your money...      2
# 213  keeps crashing \tinstalled  on the loading pag...      3
# ..                                                 ...    ...
# 60   as a commercial pilot i use this app all the t...      4
# 95   works perfect and picks up a ton of stations t...      4
# 259  awesome pdf performance\tlatest update has imp...      4
# 120  it is impossible to refine a hotel search for ...      3
# 91   this is the best app ever it make hilarious vi...      4
#
# [1405 rows x 2 columns]

# %% [markdown]
# Split Dataset

# %%
from sklearn.model_selection import train_test_split

def split_dataset(df):
  X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], test_size=0.15, random_state=42)
  return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = split_dataset(combined_df)

# %%
# tf-idf

from sklearn.feature_extraction.text import TfidfVectorizer

def fit_tfidf(X_train):
  ngram_range = (1,2)
  min_df = 0.01 # ignore terms that appear in less than 1% of the documents
  max_df = 0.9 # ignore terms that appear in more than 80% of the documents
  max_features = 300

  tfidf = TfidfVectorizer(encoding='utf-8',
                          ngram_range=ngram_range,
                          stop_words=None,
                          lowercase=False,
                          max_df=max_df,
                          min_df=min_df,
                          max_features=max_features,
                          norm='l2',
                          sublinear_tf=True)

  # Fit tf-idf vectorizer
  tfidf_vectorizer = tfidf.fit(X_train)

  return tfidf_vectorizer

# %%
# GloVe
import numpy as np

def load_glove_model(glove_file_path):
    glove_model = {}
    with open(glove_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            split_line = line.split()
            word = split_line[0]
            embedding = np.array(split_line[1:], dtype=np.float64)
            glove_model[word] = embedding
    return glove_model


glove_path = './glove/glove.6B.300d.txt'
glove_model = load_glove_model(glove_path)

# %%
def vectorize_texts(texts, glove_model, embed_dim=300):
    features = np.zeros((len(texts), embed_dim), dtype=np.float32)
    for idx, text in enumerate(texts):
        words = text.split()  # Splitting text into words
        word_count = 0
        for word in words:
            if word in glove_model:
                features[idx] += glove_model[word]
                word_count += 1
        if word_count > 0:
            features[idx] /= word_count
    return features


X_train_glove = ["This is a sample sentence.", "This is another example."]
X_train_vec = vectorize_texts(X_train_glove, glove_model)

# %%
X_train_glove
# Out:
# ['This is a sample sentence.', 'This is another example.']

# %%
tfidf = fit_tfidf(X_train)

# %%
features_train = tfidf.transform(X_train).toarray()

# %%
train_df = pd.DataFrame({
    'text': X_train,
    'label': y_train
})

# %%
train_df
# Out:
#                                                   text  label
# 130  i love\twhere are the colors of the textfonts ...      2
# 325                      i cannot open the goddamn app      1
# 98   i actually believe this app is totally awesome...      3
# 17                                very easy to use          2
# 268  the few times it worked it was an awesome app ...      1
# ..                                                 ...    ...
# 167                                just said\thuhuhuhu      2
# 288   poor in comparison with yahoo  and outlook\tpoor      2
# 189         galax s4\tcannot search for friends online      3
# 362  servers suck\ti wish servers could be better  ...      2
# 157  i am on an original ipad mini and so maybe tha...      1
#
# [1194 rows x 2 columns]

# %%
def create_pairwise_dataset(df, label1, label2):
    # Filter the DataFrame for the two labels
    pairwise_df = df[df['label'].isin([label1, label2])]
    return pairwise_df

df_bug_rating_train = create_pairwise_dataset(train_df, 1, 2)
df_bug_feature_train = create_pairwise_dataset(train_df, 1, 3)
df_bug_experience_train = create_pairwise_dataset(train_df, 1, 4)
df_rating_feature_train = create_pairwise_dataset(train_df, 2, 3)
df_rating_experience_train = create_pairwise_dataset(train_df, 2, 4)
df_experience_feature_train = create_pairwise_dataset(train_df, 4, 3)

# df_bug_rating_train = create_pairwise_dataset(train_df, 'Bug', 'Rating')
# df_bug_feature_train = create_pairwise_dataset(train_df, 'Bug', 'Feature')
# df_bug_experience_train = create_pairwise_dataset(train_df, 'Bug', 'UserExperience')
# df_rating_feature_train = create_pairwise_dataset(train_df, 'Rating', 'Feature')
# df_rating_experience_train = create_pairwise_dataset(train_df, 'Rating', 'UserExperience')
# df_experience_feature_train = create_pairwise_dataset(train_df, 'UserExperience', 'Feature')

# %%
# transform test_df using tf-idf vectorizer
features_test = tfidf.transform(X_test).toarray()
labels_test = y_test

# %%
labels_train = y_train

# %%
# transform train_dfs using tf-idf vectorizer

from sklearn.feature_extraction.text import TfidfVectorizer

def apply_tfidf(tfidf, df, text_column='text'):
  # Transform the data
  features_train = tfidf.transform(df[text_column]).toarray()

  return features_train

bug_rating_features_train = apply_tfidf(tfidf, df_bug_rating_train)
bug_feature_features_train = apply_tfidf(tfidf, df_bug_feature_train)
bug_experience_features_train = apply_tfidf(tfidf, df_bug_experience_train)
rating_feature_features_train = apply_tfidf(tfidf, df_rating_feature_train)
rating_experience_features_train = apply_tfidf(tfidf, df_rating_experience_train)
experience_feature_features_train = apply_tfidf(tfidf, df_experience_feature_train)

# %%
# transform train_dfs and test features using GloVe vectorizer

features_test_glove = vectorize_texts(X_test, glove_model)

bug_rating_features_train_glove = vectorize_texts(df_bug_rating_train['text'], glove_model)
bug_feature_features_train_glove = vectorize_texts(df_bug_feature_train['text'], glove_model)
bug_experience_features_train_glove = vectorize_texts(df_bug_experience_train['text'], glove_model)
rating_feature_features_train_glove = vectorize_texts(df_rating_feature_train['text'], glove_model)
rating_experience_features_train_glove = vectorize_texts(df_rating_experience_train['text'], glove_model)
experience_feature_features_train_glove = vectorize_texts(df_experience_feature_train['text'], glove_model)

# %%
# training labels
bug_rating_labels_train = df_bug_rating_train['label']
bug_feature_labels_train = df_bug_feature_train['label']
bug_experience_labels_train = df_bug_experience_train['label']
rating_feature_labels_train = df_rating_feature_train['label']
rating_experience_labels_train = df_rating_experience_train['label']
experience_feature_labels_train = df_experience_feature_train['label']

# %% [markdown]
# One vs One

# %% [markdown]
# Train SVM model with Random Search hyperparameter tuning

# %%
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
import numpy as np

def train_svm_model(features, labels, label_column='label'):
    le = LabelEncoder()
    encoded_labels = le.fit_transform(labels)
    svm = SVC()

    # hyperparameter options
    C = [.0001, .001,  .1, 1]
    gamma = [.0001, .001, .01, .1, 1, 10, 100]
    degree = [1, 2, 3, 4, 5]
    kernel = ['linear', 'rbf', 'poly']
    probability = [True]

    # Create the param grid
    param_grid = {'C': C,
                  'kernel': kernel,
                  'gamma': gamma,
                  'degree': degree,
                  'probability': probability
                }

    # Setup the random search with cross-validation
    random_search = RandomizedSearchCV(svm,
                                       param_distributions=param_grid,
                                       n_iter=50,
                                       scoring='f1',
                                       cv=5,
                                       verbose=1,
                                       random_state=42,
                                       )

    # Fit the random search model
    random_search.fit(features, encoded_labels)
    

    print("Best parameters found: ", random_search.best_params_)
    print("Best cross-validated score achieved: ", random_search.best_score_)

    best_svc = random_search.best_estimator_
    return best_svc.fit(features, encoded_labels)

# %% [markdown]
# Train Binary Classifiers

# %%
classifiers = {
    'bug_rating': train_svm_model(bug_rating_features_train, bug_rating_labels_train),
    'bug_feature': train_svm_model(bug_feature_features_train, bug_feature_labels_train),
    'bug_experience': train_svm_model(bug_experience_features_train, bug_experience_labels_train) ,
    'rating_feature': train_svm_model(rating_feature_features_train, rating_feature_labels_train),
    'rating_experience': train_svm_model(rating_experience_features_train, rating_experience_labels_train),
    'experience_feature': train_svm_model(experience_feature_features_train, experience_feature_labels_train)
}
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'linear', 'gamma': 1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.8255669425529801
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 10, 'degree': 2, 'C': 1}
# Best cross-validated score achieved:  0.5815247890120995
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'rbf', 'gamma': 0.1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.8575660362813741
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'linear', 'gamma': 1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.7794401066734385
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# ...

# %%
classifiers_glove = {
    'bug_rating': train_svm_model(bug_rating_features_train_glove, bug_rating_labels_train),
    'bug_feature': train_svm_model(bug_feature_features_train_glove, bug_feature_labels_train),
    'bug_experience': train_svm_model(bug_experience_features_train_glove, bug_experience_labels_train),
    'rating_feature': train_svm_model(rating_feature_features_train_glove, rating_feature_labels_train),
    'rating_experience': train_svm_model(rating_experience_features_train_glove, rating_experience_labels_train),
    'experience_feature': train_svm_model(experience_feature_features_train_glove, experience_feature_labels_train)
}
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'rbf', 'gamma': 0.1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.8258584897144938
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 10, 'degree': 5, 'C': 1}
# Best cross-validated score achieved:  0.5851157801942388
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 0.1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.8734128233970754
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'rbf', 'gamma': 0.1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.8380548192666399
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# ...

# %%
predictions = {
    key: classifiers[key].predict(features_test)
    for key in classifiers
}

# %%
predictions_glove = {
    key: classifiers_glove[key].predict(features_test_glove)
    for key in classifiers_glove
}

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, accuracy_score, recall_score, precision_score
from scipy.stats import mode

def aggregate_predictions(classifier_mappings, predictions):
    label_predictions = [[] for _ in range(len(predictions['bug_rating']))]

    # Aggregate predictions for each classifier
    for key, pred in predictions.items():
        class1, class2 = classifier_mappings[key]
        for i, p in enumerate(pred):
            # Map binary prediction back to original labels
            actual_label = class1 if p == 0 else class2
            label_predictions[i].append(actual_label)

    # Determine the most common label for each instance
    final_predictions = [mode(preds)[0] for preds in label_predictions]
    return final_predictions

classifier_mappings = {
    'bug_rating': (1, 2),
    'bug_feature': (1, 3),
    'bug_experience': (1, 4),
    'rating_feature': (2, 3),
    'rating_experience': (2, 4),
    'experience_feature': (3, 4)
}

# %%
final_predictions = aggregate_predictions(classifier_mappings, predictions)

# %%
final_predictions_glove = aggregate_predictions(classifier_mappings, predictions_glove)

# %%
train_predictions = {
    key: classifiers[key].predict(features_train)
    for key in classifiers
}

# %%
# encode labels
label_mapping = {
    'Bug': 1,
    'Rating': 2,
    'Feature': 3,
    'UserExperience': 4
}
labels_test = labels_test.replace(label_mapping)
labels_train = labels_train.replace(label_mapping)

# %%
train_predictions_final = aggregate_predictions(classifier_mappings, train_predictions)

# %%
f1_score(labels_train, train_predictions_final, average=None)
# Out:
# array([0.85337727, 0.68358714, 0.83966245, 0.7150838 ])

# %%
f1_score(labels_test, final_predictions, average=None)
# Out:
# array([0.5982906 , 0.60784314, 0.5       , 0.57142857])

# %%
f1_score(labels_test, final_predictions_glove, average=None)
# Out:
# array([0.58730159, 0.61538462, 0.40449438, 0.55172414])

# %%
accuracy_score(labels_train, train_predictions_final)
# Out:
# 0.7671691792294807

# %%
accuracy_score(labels_test, final_predictions)
# Out:
# 0.5734597156398105

# %%
accuracy_score(labels_test, final_predictions_glove)
# Out:
# 0.5450236966824644

# %% [markdown]
# One vs All

# %%
# Create OnevAll Datasets

def create_one_vs_all_dataset(df, target_label, label_column='label'):
    df_binary = df.copy()

    # Apply the binary conversion: 1 if the label is the target_label, else 0
    df_binary[label_column] = (
        df_binary[label_column] == target_label).astype(int)

    return df_binary


df_bug_rest_train = create_one_vs_all_dataset(train_df, target_label=1)
df_rating_rest_train = create_one_vs_all_dataset(train_df, target_label=2)
df_feature_rest_train = create_one_vs_all_dataset(train_df, target_label=3)
df_experience_rest_train = create_one_vs_all_dataset(train_df, target_label=4)

# %%
# create training features and apply tfidf

bug_rest_features_train = apply_tfidf(tfidf, df_bug_rest_train)
rating_rest_features_train = apply_tfidf(tfidf, df_rating_rest_train)
feature_rest_features_train = apply_tfidf(tfidf, df_feature_rest_train)
experience_rest_features_train = apply_tfidf(tfidf, df_experience_rest_train)

# %%
# create training features and apply GloVe

bug_rest_features_train_glove = bug_rest_features_train_glove = vectorize_texts(df_bug_rest_train['text'], glove_model)
rating_rest_features_train_glove = bug_rest_features_train_glove = vectorize_texts(df_rating_rest_train['text'], glove_model)
feature_rest_features_train_glove = bug_rest_features_train_glove = vectorize_texts(df_feature_rest_train['text'], glove_model)
experience_rest_features_train_glove = bug_rest_features_train_glove = vectorize_texts(df_experience_rest_train['text'], glove_model)

# %%
# create train lables

bug_rest_labels_train = df_bug_rest_train['label']
rating_rest_labels_train = df_rating_rest_train['label']
feature_rest_labels_train = df_feature_rest_train['label']
experience_rest_labels_train = df_experience_rest_train['label']

# %%
# train OnevAll tf-idf models

classifiers_onevall_tfidf = {
    'bug_rest': train_svm_model(bug_rest_features_train, bug_rest_labels_train),
    'rating_rest': train_svm_model(rating_rest_features_train, rating_rest_labels_train),
    'feature_rest': train_svm_model(feature_rest_features_train, feature_rest_labels_train),
    'experience_rest': train_svm_model(experience_rest_features_train, experience_rest_labels_train),
}
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'linear', 'gamma': 1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.5278223841107197
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 10, 'degree': 2, 'C': 1}
# Best cross-validated score achieved:  0.5329674383587427
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 10, 'degree': 2, 'C': 1}
# Best cross-validated score achieved:  0.34114134353155073
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'linear', 'gamma': 1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.47101121986642525

# %%
# train OnevAll GloVe models

classifiers_onevall_glove = {
    'bug_rest': train_svm_model(bug_rest_features_train_glove, bug_rest_labels_train),
    'rating_rest': train_svm_model(rating_rest_features_train_glove, rating_rest_labels_train),
    'feature_rest': train_svm_model(feature_rest_features_train_glove, feature_rest_labels_train),
    'experience_rest': train_svm_model(experience_rest_features_train_glove, experience_rest_labels_train),
}
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 10, 'degree': 5, 'C': 1}
# Best cross-validated score achieved:  0.5393250714406358
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'rbf', 'gamma': 0.1, 'degree': 3, 'C': 1}
# Best cross-validated score achieved:  0.5483266651051839
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 10, 'degree': 2, 'C': 1}
# Best cross-validated score achieved:  0.39428538313968453
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best parameters found:  {'probability': True, 'kernel': 'poly', 'gamma': 10, 'degree': 5, 'C': 1}
# Best cross-validated score achieved:  0.49186951679035235

# %%
predictions_onevall_tfidf = {
    key: classifiers_onevall_tfidf[key].predict_proba(features_test)[:, 1]
    for key in classifiers_onevall_tfidf
}

# %%
predictions_onevall_glove = {
    key: classifiers_onevall_glove[key].predict_proba(features_test_glove)[:, 1]
    for key in classifiers_onevall_glove
}

# %%
classifier_mappings_onevall = {
    'bug_rest': (1, 2),
    'bug_feature': (1, 3),
    'bug_experience': (1, 4),
    'rating_feature': (2, 3),
}

# %%
def aggregate_predictions(probabilities_dict):
    """
    Aggregates predictions from multiple classifiers by selecting the class
    with the highest probability for each instance.

    Parameters:
    - probabilities_dict (dict): A dictionary where each key is a class label
      and each value is an array of probabilities for that class.

    Returns:
    - np.array: An array of predicted class labels, where each label is the one
      with the highest probability for each instance.
    """

    # Create a list of probability arrays in a consistent order
    prob_list = [probabilities_dict[key] for key in probabilities_dict]

    # Stack these arrays horizontally to form a matrix
    prob_matrix = np.vstack(prob_list).T

    # Find the index of the maximum probability for each instance
    predicted_indices = np.argmax(prob_matrix, axis=1)

    # Assuming class labels correspond to the index+1 (1-indexed)
    predicted_labels = predicted_indices + 1

    return predicted_labels

# %%
final_predictions_onevall_tfidf = aggregate_predictions(predictions_onevall_tfidf)

# %%
f1_score(labels_test, final_predictions_onevall_tfidf, average=None)
# Out:
# array([0.63247863, 0.60784314, 0.54347826, 0.54054054])

# %%
accuracy_score(labels_test, final_predictions_onevall_tfidf)
# Out:
# 0.5829383886255924

# %%
final_predictions_onevall_glove = aggregate_predictions(
    predictions_onevall_glove)

# %%
f1_score(labels_test, final_predictions_onevall_glove, average=None)
# Out:
# array([0.58015267, 0.58947368, 0.31818182, 0.48148148])

# %%
accuracy_score(labels_test, final_predictions_onevall_glove)
# Out:
# 0.5023696682464455
